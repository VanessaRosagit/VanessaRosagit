# %% [markdown]
# <a href="https://colab.research.google.com/github/VanessaRosagit/VanessaRosagit/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dicionario = {
    "João": 20,
    "Maria": 30,
    "Pedro": 35,
    "Julia": 18
}
print(dicionario.items())

print(dicionario.keys())

dicionario2 = {
    "Jose": 22,
    "Paula": 33
}
dicionario.update(dicionario2)
print(dicionario)
{
 'João': 20,
 'Maria': 30,
 'Pedro': 35,
 'Julia': 18,
 'Jose': 22,
 'Paula': 33
}
# Out:
# dict_items([('João', 20), ('Maria', 30), ('Pedro', 35), ('Julia', 18)])
# dict_keys(['João', 'Maria', 'Pedro', 'Julia'])
# {'João': 20, 'Maria': 30, 'Pedro': 35, 'Julia': 18, 'Jose': 22, 'Paula': 33}
# {'João': 20, 'Maria': 30, 'Pedro': 35, 'Julia': 18, 'Jose': 22, 'Paula': 33}
